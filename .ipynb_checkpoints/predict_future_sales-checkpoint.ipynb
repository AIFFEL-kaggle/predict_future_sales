# %% [markdown]
# ### < 모델 생성 후 고려해볼 것들>
# 1. 모델을 여러가지 사용해보기 ex) 앙상블, XGBoost, Light GBM, LSTM
# 2. 이상치를 중앙값으로 할지, 최대치로 할지
# 3. 시계열 데이터를 어떻게 처리할지 ex) 4분기, 2분기 등
# 4. 판매량, 판매 가격의 데이터 쏠림을 전처리 할지 말지
# -> 팀당 하루에 5번 제출 가능

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from os.path import join
from sklearn.preprocessing import LabelEncoder

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # 1. 데이터 불러오기

# %%
data_dir = os.getenv('HOME') + '/kaggle/predict_future_sales/data'
# data_dir = os.getenv('HOME')+'/aiffel/hac1/'

items_path = os.path.join(data_dir, 'items.csv')
item_category_path = os.path.join(data_dir, 'item_categories.csv')
shops_path = os.path.join(data_dir, 'shops.csv')
train_path = os.path.join(data_dir, 'sales_train.csv')
test_path = os.path.join(data_dir, 'test.csv')

# %%
items = pd.read_csv(items_path)
categories = pd.read_csv(item_category_path)
shops = pd.read_csv(shops_path)
train = pd.read_csv(train_path)
test = pd.read_csv(test_path)

# %% [markdown]
# # 2. 데이터 분석

# %% [markdown]
# * 파일 설명
#
#
# sales_train.csv- 훈련 세트. 2013 년 1 월부터 2015 년 10 월까지의 일일 기록 데이터.
# test.csv- 테스트 세트. 이러한 상점과 제품의 2015 년 11 월 매출을 예측해야합니다.
# sample_submission.csv- 올바른 형식의 샘플 제출 파일.
# items.csv- 항목 / 제품에 대한 추가 정보.
# item_categories.csv- 항목 카테고리에 대한 추가 정보입니다.
# shops.csv- 상점에 대한 추가 정보.
#
# * 데이터 필드
#
#
# ID- 테스트 세트 내에서 (Shop, Item) 튜플을 나타내는 Id
# shop_id- 상점의 고유 식별자
# item_id- 상품의 고유 식별자
# item_category_id- 항목 카테고리의 고유 식별자
# item_cnt_day- 판매 된 제품 수입니다. 이 측정 값의 월별 금액을 예측하고 있습니다.
# item_price- 상품의 현재 가격
# date -dd / mm / yyyy 형식의 날짜
# date_block_num- 편의를 위해 사용되는 연속 된 월 번호. 2013 년 1 월은 0, 2013 년 2 월은 1, ..., 2015 년 10 월은 33입니다.
# item_name- 항목 이름
# shop_name- 상점 이름
# item_category_name- 항목 카테고리 이름

# %%
data = pd.read_csv(train_path)
sub = pd.read_csv(test_path)
print('train data dim : {}'.format(data.shape))
print('test data dim : {}'.format(sub.shape))
# Out:
# train data dim : (2935849, 6)
# test data dim : (214200, 3)

# %% [markdown]
# 학습데이터는 100만개, 테스트 데이터는 21만개로 이루어져 있음.
# test 데이터의 컬럼이 3개인것을 볼 수 있는데, 제외된 3개의 컬럼 중 하나는 우리가 마주어야 할 집의 가격 `price`일 것임

# %%
items.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1  !ABBYY FineReader 12 Professional Edition Full...        1
# 2      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 3    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 4        ***КОРОБКА (СТЕКЛО)                       D        4
#
#    item_category_id
# 0                40
# 1                76
# 2                40
# 3                40
# 4                40

# %%
categories.head()
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
shops.head()
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %%
train.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
test.head()
# Out:
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233
# 3   3        5     5232
# 4   4        5     5268

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
# train['shop_id'].value_counts()

# %%
# test['shop_id'].value_counts()

# %% [markdown]
# # 3. Feature Engineering

# %% [markdown]
# #### 3.1 데이터 결측치 확인

# %%
train.isnull().sum()
# Out:
# date              0
# date_block_num    0
# shop_id           0
# item_id           0
# item_price        0
# item_cnt_day      0
# dtype: int64

# %% [markdown]
# #### 3.2 중복 제거

# %%
sum(train.duplicated()), sum(test.duplicated())
# Out:
# (6, 0)

# %%
train[train.duplicated() == True]
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 76962    05.01.2013               0       54    20130       149.0
# 1435367  23.02.2014              13       50     3423       999.0
# 1496766  23.03.2014              14       21     3423       999.0
# 1671873  01.05.2014              16       50     3423       999.0
# 1866340  12.07.2014              18       25     3423       999.0
# 2198566  31.12.2014              23       42    21619       499.0
#
#          item_cnt_day
# 76962             1.0
# 1435367           1.0
# 1496766           1.0
# 1671873           1.0
# 1866340           1.0
# 2198566           1.0

# %%
train.drop_duplicates(inplace=True)

# %%
#중복 재확인
sum(train.duplicated())
# Out:
# 0

# %% [markdown]
# #### 3.3 이상치 제거(진오님)

# %% [markdown]
# * 가격 이상치 제거

# %%
plt.figure(figsize=(7,6))
train.boxplot(column=['item_price'])
plt.show()

# %%
train[train['item_price']>=50000]
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 885138   17.09.2013               8       12    11365     59200.0
# 1163158  13.12.2013              11       12     6066    307980.0
# 1488135  20.03.2014              14       25    13199     50999.0
#
#          item_cnt_day
# 885138            1.0
# 1163158           1.0
# 1488135           1.0

# %%
train_1 = train[train['item_price']<=100000]
train_1
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 2935844           1.0
# 2935845           1.0
# 2935846           1.0
# 2935847           1.0
# 2935848           1.0
#
# [2935842 rows x 6 columns]

# %% [markdown]
# * 일당 판매량 이상치 제거

# %%
plt.figure(figsize=(7,6))
train_1.boxplot(column=['item_cnt_day'])
plt.show()

# %%
train_1[train_1['item_cnt_day']>=500]
# Out:
#                date  date_block_num  shop_id  item_id   item_price  \
# 1573253  22.04.2014              15       27     8057  1200.000000
# 1708207  28.06.2014              17       25    20949     5.000000
# 2048518  02.10.2014              21       12     9242  1500.000000
# 2067669  09.10.2014              21       55    19437   899.000000
# 2257299  19.12.2014              23       12    20949     4.000000
# 2326930  15.01.2015              24       12    20949     4.000000
# 2608040  14.04.2015              27       12     3731  1904.548077
# 2626181  19.05.2015              28       12    11373   155.192950
# 2851073  29.09.2015              32       55     9249  1500.000000
# 2851091  30.09.2015              32       55     9249  1702.825746
# 2864235  30.09.2015              32       12     9248  1692.526158
# 2864260  29.09.2015              32       12     9248  1500.000000
# 2909401  14.10.2015              33       12    20949     4.000000
# 2909818  28.10.2015              33       12    11373     0.908714
#
#          item_cnt_day
# 1573253         502.0
# 1708207         501.0
# 2048518         512.0
# 2067669         508.0
# 2257299         500.0
# 2326930        1000.0
# 2608040         624.0
# 2626181         539.0
# 2851073         533.0
# 2851091         637.0
# 2864235         669.0
# 2864260         504.0
# 2909401         500.0
# 2909818        2169.0

# %%
train_1 = train_1[train_1['item_cnt_day']<=500]
train_1
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# 2935844           1.0
# 2935845           1.0
# 2935846           1.0
# 2935847           1.0
# 2935848           1.0
#
# [2935830 rows x 6 columns]

# %% [markdown]
# * 값을 정렬해보니 마이너스값 존재해서 제거

# %%
train_1.sort_values('item_price', axis=0, ascending=False)
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 885138   17.09.2013               8       12    11365  59200.0000
# 1488135  20.03.2014              14       25    13199  50999.0000
# 2327159  29.01.2015              24       12     7241  49782.0000
# 2931380  20.10.2015              33       22    13403  42990.0000
# 2917760  20.10.2015              33        3    13403  42990.0000
# ...             ...             ...      ...      ...         ...
# 673155   31.07.2013               6        6    11872      0.0900
# 611400   08.06.2013               5       58    20146      0.0875
# 608763   08.06.2013               5       58    11865      0.0700
# 579766   11.06.2013               5        6    11864      0.0700
# 484683   15.05.2013               4       32     2973     -1.0000
#
#          item_cnt_day
# 885138            1.0
# 1488135           1.0
# 2327159           1.0
# 2931380           1.0
# 2917760           1.0
# ...               ...
# 673155            1.0
# 611400            4.0
# 608763            1.0
# 579766            1.0
# 484683            1.0
#
# [2935830 rows x 6 columns]

# %%
train_1 = train_1[train_1['item_price'] != -1.0000]

# %% [markdown]
# * 최종 결과

# %%
train_1.shape
# Out:
# (2935829, 6)

# %% [markdown]
# #### 3.4 아이템 대분류 만들기(은지님 추가)

# %%
# categories 내에서 main_category분할 후 index설정
categories['main_category'] = categories['item_category_name'].str.split(' - ').map(lambda x:x[0])
le = LabelEncoder()
categories['main_category_id'] = le.fit_transform(categories['main_category'])
categories.head()
# Out:
#         item_category_name  item_category_id main_category  main_category_id
# 0  PC - Гарнитуры/Наушники                 0            PC                 0
# 1         Аксессуары - PS2                 1    Аксессуары                 1
# 2         Аксессуары - PS3                 2    Аксессуары                 1
# 3         Аксессуары - PS4                 3    Аксессуары                 1
# 4         Аксессуары - PSP                 4    Аксессуары                 1

# %%
# items에 categories merge
items = pd.merge(items, categories, on="item_category_id")
items.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 2    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 3        ***КОРОБКА (СТЕКЛО)                       D        4
# 4  ***НОВЫЕ АМЕРИКАНСКИЕ ГРАФФИТИ  (UNI)         ...        5
#
#    item_category_id item_category_name main_category  main_category_id
# 0                40         Кино - DVD          Кино                11
# 1                40         Кино - DVD          Кино                11
# 2                40         Кино - DVD          Кино                11
# 3                40         Кино - DVD          Кино                11
# 4                40         Кино - DVD          Кино                11

# %%
del items['item_category_name']
del items['main_category']
items.head()
# Out:
#                                            item_name  item_id  \
# 0          ! ВО ВЛАСТИ НАВАЖДЕНИЯ (ПЛАСТ.)         D        0
# 1      ***В ЛУЧАХ СЛАВЫ   (UNV)                    D        2
# 2    ***ГОЛУБАЯ ВОЛНА  (Univ)                      D        3
# 3        ***КОРОБКА (СТЕКЛО)                       D        4
# 4  ***НОВЫЕ АМЕРИКАНСКИЕ ГРАФФИТИ  (UNI)         ...        5
#
#    item_category_id  main_category_id
# 0                40                11
# 1                40                11
# 2                40                11
# 3                40                11
# 4                40                11

# %%
train = pd.merge(train, items, on="item_id")

# %%
train.tail()
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 2935838  17.10.2015              33       25     8428       249.0
# 2935839  01.10.2015              33       25     7903     12198.0
# 2935840  29.10.2015              33       25     7610      2890.0
# 2935841  22.10.2015              33       25     7635      2100.0
# 2935842  01.10.2015              33       25     7640      4040.0
#
#          item_cnt_day                                          item_name  \
# 2935838           1.0                       АХ, ВОДЕВИЛЬ, ВОДЕВИЛЬ (rem)
# 2935839           1.0  XBOX 360 S 250GB CONSOLE/KINECT BUNDLE KUNG FU...
# 2935840           1.0      WARHAMMER ACCESSORIES: Khorne Dice арт. 65-13
# 2935841           1.0  WARHAMMER MINIATURES: Dark Elf Doomfire Warloc...
# 2935842           1.0  WARHAMMER MINIATURES: Stormcast Eternals Palad...
#
#          item_category_id  main_category_id
# 2935838                40                11
# 2935839                15                 4
# 2935840                64                14
# 2935841                64                14
# 2935842                64                14

# %% [markdown]
# #### 3.5 지역별 가게 대분류 만들기

# %%
shop_data_path = join(data_dir, 'shops.csv')
shops = pd.read_csv(shop_data_path)
pd.DataFrame(shops.shop_name.values.reshape(-1, 4))
# Out:
#                                                   0  \
# 0                     !Якутск Орджоникидзе, 56 фран
# 1                          Волжский ТЦ "Волга Молл"
# 2                      Воронеж ТРЦ Сити-Парк "Град"
# 3                               Интернет-магазин ЧС
# 4                                  Коломна ТЦ "Рио"
# 5                               Москва "Распродажа"
# 6                  Москва ТК "Буденовский" (пав.К7)
# 7                   Москва ТЦ "МЕГА Теплый Стан" II
# 8                        Москва ТЦ "Серебряный Дом"
# 9             Новосибирск ТРЦ "Галерея Новосибирск"
# 10  РостовНаДону ТРК "Мегацентр Горизонт" Островной
# 11                              Самара ТЦ "Мелодия"
# 12                     Томск ТРЦ "Изумрудный Город"
# 13                             Уфа ТК "Центральный"
# 14                             Чехов ТРЦ "Карнавал"
#
#                                      1                            2  \
# 0        !Якутск ТЦ "Центральный" фран             Адыгея ТЦ "Мега"
# 1               Вологда ТРЦ "Мармелад"   Воронеж (Плехановская, 13)
# 2                    Выездная Торговля   Жуковский ул. Чкалова 39м?
# 3                  Казань ТЦ "Бехетле"      Казань ТЦ "ПаркХаус" II
# 4        Красноярск ТЦ "Взлетка Плаза"         Красноярск ТЦ "Июнь"
# 5               Москва МТРЦ "Афи Молл"           Москва Магазин С21
# 6                  Москва ТРК "Атриум"  Москва ТЦ "Ареал" (Беляево)
# 7   Москва ТЦ "Новый век" (Новокосино)       Москва ТЦ "Перловский"
# 8                    Мытищи ТРК "XL-3"         Н.Новгород ТРЦ "РИО"
# 9                Новосибирск ТЦ "Мега"               Омск ТЦ "Мега"
# 10              РостовНаДону ТЦ "Мега"       СПб ТК "Невский Центр"
# 11                Самара ТЦ "ПаркХаус"        Сергиев Посад ТЦ "7Я"
# 12               Тюмень ТРЦ "Кристалл"           Тюмень ТЦ "Гудвин"
# 13                    Уфа ТЦ "Семья" 2              Химки ТЦ "Мега"
# 14             Якутск Орджоникидзе, 56      Якутск ТЦ "Центральный"
#
#                                         3
# 0          Балашиха ТРК "Октябрь-Киномир"
# 1                  Воронеж ТРЦ "Максимир"
# 2              Жуковский ул. Чкалова 39м²
# 3                    Калуга ТРЦ "XXI век"
# 4                   Курск ТЦ "Пушкинский"
# 5        Москва ТК "Буденовский" (пав.А2)
# 6          Москва ТЦ "МЕГА Белая Дача II"
# 7                 Москва ТЦ "Семеновский"
# 8             Н.Новгород ТРЦ "Фантастика"
# 9   РостовНаДону ТРК "Мегацентр Горизонт"
# 10                        СПб ТК "Сенная"
# 11                 Сургут ТРЦ "Сити Молл"
# 12              Тюмень ТЦ "Зеленый Берег"
# 13               Цифровой склад 1С-Онлайн
# 14                 Ярославль ТЦ "Альтаир"

# %%
shops['city'] = shops['shop_name'].str.split(' ').map(lambda x: x[0])
shops.loc[shops.city == '!Якутск', 'city'] = 'Якутск'
shops.head(10)
# Out:
#                         shop_name  shop_id      city
# 0   !Якутск Орджоникидзе, 56 фран        0    Якутск
# 1   !Якутск ТЦ "Центральный" фран        1    Якутск
# 2                Адыгея ТЦ "Мега"        2    Адыгея
# 3  Балашиха ТРК "Октябрь-Киномир"        3  Балашиха
# 4        Волжский ТЦ "Волга Молл"        4  Волжский
# 5          Вологда ТРЦ "Мармелад"        5   Вологда
# 6      Воронеж (Плехановская, 13)        6   Воронеж
# 7          Воронеж ТРЦ "Максимир"        7   Воронеж
# 8    Воронеж ТРЦ Сити-Парк "Град"        8   Воронеж
# 9               Выездная Торговля        9  Выездная

# %%
# 문자 데이터를 모두 수치 데이터로 Encoding
shops.city.value_counts()
# Out:
# Москва              13
# Якутск               4
# РостовНаДону         3
# Воронеж              3
# Тюмень               3
# Казань               2
# СПб                  2
# Уфа                  2
# Красноярск           2
# Новосибирск          2
# Н.Новгород           2
# Самара               2
# Жуковский            2
# Цифровой             1
# Химки                1
# Омск                 1
# Адыгея               1
# Ярославль            1
# Калуга               1
# Сургут               1
# Чехов                1
# Курск                1
# Томск                1
# Сергиев              1
# Коломна              1
# Волжский             1
# Выездная             1
# Мытищи               1
# Интернет-магазин     1
# Вологда              1
# Балашиха             1
# Name: city, dtype: int64

# %%
city_encoder = LabelEncoder()
shops['city_code'] = city_encoder.fit_transform(shops['city'])
shops = shops[['shop_id', 'city_code']]
shops.head()
# Out:
#    shop_id  city_code
# 0        0         29
# 1        1         29
# 2        2          0
# 3        3          1
# 4        4          2

# %% [markdown]
# #### train 데이터에 city_code, item_code 추가하기

# %%
merged_df = pd.merge(train, shops, on="shop_id")
merged_df
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154       999.0
# 1        16.05.2013               4       59     2573       249.0
# 2        26.01.2013               0       59     2574       399.0
# 3        09.01.2013               0       59     2574       399.0
# 4        24.02.2013               1       59     2574       399.0
# ...             ...             ...      ...      ...         ...
# 2935838  28.10.2015              33       55     1819      1499.0
# 2935839  29.10.2015              33       55     1819      1499.0
# 2935840  24.10.2015              33       55     2390        99.0
# 2935841  01.10.2015              33       55     1935       249.0
# 2935842  17.10.2015              33       55     2066       199.0
#
#          item_cnt_day                                          item_name  \
# 0                 1.0                                  ЯВЛЕНИЕ 2012 (BD)
# 1                 1.0                          DEL REY LANA  Born To Die
# 2                 1.0  DEL REY LANA  Born To Die  The Paradise Editio...
# 3                 1.0  DEL REY LANA  Born To Die  The Paradise Editio...
# 4                 1.0  DEL REY LANA  Born To Die  The Paradise Editio...
# ...               ...                                                ...
# 2935838           3.0  Batman: Рыцарь Аркхема. Premium Edition [PC, Ц...
# 2935839           1.0  Batman: Рыцарь Аркхема. Premium Edition [PC, Ц...
# 2935840           1.0                     Cold War [PC, Цифровая версия]
# 2935841           1.0  BioShock 2. Minerva's Den (дополнение) [PC, Ци...
# 2935842           1.0  Brothers in Arms: Earned in Blood (Бука) [PC, ...
#
#          item_category_id  main_category_id  city_code
# 0                      37                11         30
# 1                      55                13         30
# 2                      55                13         30
# 3                      55                13         30
# 4                      55                13         30
# ...                   ...               ...        ...
# 2935838                31                 8         27
# 2935839                31                 8         27
# 2935840                31                 8         27
# 2935841                31                 8         27
# 2935842                31                 8         27
#
# [2935843 rows x 10 columns]

# %% [markdown]
# ### 3.7 월별 합치기
# shop_id, item_id, date_block_num이 같으면 데이터 합치기

# %%
df_month = merged_df.groupby(by=['shop_id', 'item_id', 'date_block_num']).agg({'item_cnt_day':['sum']})
df_month.head(30)
# Out:
#                                item_cnt_day
#                                         sum
# shop_id item_id date_block_num
# 0       30      1                      31.0
#         31      1                      11.0
#         32      0                       6.0
#                 1                      10.0
#         33      0                       3.0
#                 1                       3.0
#         35      0                       1.0
#                 1                      14.0
#         36      1                       1.0
#         40      1                       1.0
#         42      1                       1.0
#         43      0                       1.0
#         49      1                       2.0
#         51      0                       2.0
#                 1                       3.0
#         57      1                       1.0
#         59      1                       1.0
#         61      0                       1.0
#         75      0                       1.0
#         85      1                       1.0
#         88      0                       1.0
#         95      0                       1.0
#         96      0                       1.0
#         97      1                       1.0
#         98      0                      25.0
#                 1                       5.0
#         111     0                       1.0
#                 1                       1.0
#         115     1                       1.0
#         136     1                       1.0

# %%
train = merged_df.drop_duplicates(subset=['shop_id', 'item_id', 'date_block_num'])
# before row count : 2935843
# after row count : 1609124

# %%
df_month = pd.DataFrame(df_month)
train = pd.merge(left=train, right=df_month, on=['shop_id', 'item_id', 'date_block_num'])
train.head()
# Out:
# /home/ssac12/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py:618: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0  02.01.2013               0       59    22154       999.0           1.0
# 1  16.05.2013               4       59     2573       249.0           1.0
# 2  26.01.2013               0       59     2574       399.0           1.0
# 3  24.02.2013               1       59     2574       399.0           1.0
# 4  29.03.2013               2       59     2574       399.0           1.0
#
#                                            item_name  item_category_id  \
# 0                                  ЯВЛЕНИЕ 2012 (BD)                37
# 1                          DEL REY LANA  Born To Die                55
# 2  DEL REY LANA  Born To Die  The Paradise Editio...                55
# 3  DEL REY LANA  Born To Die  The Paradise Editio...                55
# 4  DEL REY LANA  Born To Die  The Paradise Editio...                55
#
#    main_category_id  city_code  (item_cnt_day, sum)
# 0                11         30                  1.0
# 1                13         30                  1.0
# 2                13         30                  2.0
# 3                13         30                  1.0
# 4                13         30                  1.0

# %% [markdown]
# ### 3.8 분기별 나누기

# %% [markdown]
# ### 3.9 필요없는 컬럼 삭제

# %%
del train['date']
del train['item_cnt_day']
del train['item_name']

print(train.shape)
train.head()
# Out:
# (1609124, 8)
#    date_block_num  shop_id  item_id  item_price  item_category_id  \
# 0               0       59    22154       999.0                37
# 1               4       59     2573       249.0                55
# 2               0       59     2574       399.0                55
# 3               1       59     2574       399.0                55
# 4               2       59     2574       399.0                55
#
#    main_category_id  city_code  (item_cnt_day, sum)
# 0                11         30                  1.0
# 1                13         30                  1.0
# 2                13         30                  2.0
# 3                13         30                  1.0
# 4                13         30                  1.0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1609124 entries, 0 to 1609123
# Data columns (total 8 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   date_block_num       1609124 non-null  int64
#  1   shop_id              1609124 non-null  int64
#  2   item_id              1609124 non-null  int64
#  3   item_price           1609124 non-null  float64
#  4   item_category_id     1609124 non-null  int64
#  5   main_category_id     1609124 non-null  int64
#  6   city_code            1609124 non-null  int64
#  7   (item_cnt_day, sum)  1609124 non-null  float64
# dtypes: float64(2), int64(6)
# memory usage: 110.5 MB

# %%
print(train.columns)
# Out:
# Index([       'date_block_num',               'shop_id',
#                      'item_id',            'item_price',
#             'item_category_id',      'main_category_id',
#                    'city_code', ('item_cnt_day', 'sum')],
#       dtype='object')

# %%
y = train[('item_cnt_day', 'sum')]
x = train

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import KFold, cross_val_score
import xgboost as xgb
import lightgbm as lgb

# %%
gboost = GradientBoostingRegressor(random_state=2019)
xgboost = xgb.XGBRegressor(random_state=2019)
lightgbm = lgb.LGBMRegressor(random_state=2019)

models = [{'model':gboost, 'name':'GradientBoosting'}, {'model':xgboost, 'name':'XGBoost'},
          {'model':lightgbm, 'name':'LightGBM'}]

print('얍💢')
# Out:
# 얍💢

# %%
def get_cv_score(models):
    kfold = KFold(n_splits=5, random_state=2019).get_n_splits(x.values)
    for m in models:
        print("Model {} CV score : {:.4f}".format(m['name'], np.mean(cross_val_score(m['model'], x.values, y)), 
                                                  kf=kfold))
print('얍💢')
# Out:
# 얍💢

# %%
get_cv_score(models)
